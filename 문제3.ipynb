# %% [markdown]
# 1. titanic 데이터를 로드 한 뒤 전체 승객을 나이별로 히스토그램으로 나타내세요.
#
# 2. 남,여 승객수를 나타내세요.

# %%
import seaborn as sns
titanics = sns.load_dataset("titanic")
print(titanics.head())
print(type(titanics))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>

# %%
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False # - 기호 깨지는것 방지
#f_path = "/Library/Fonts/AppleGothic.ttf" (맥)
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
hist = plt.subplots()
hist = sns.distplot(titanics['age'])
hist.set_title('Histogram of Age')
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_6968\176128015.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   hist = sns.distplot(titanics['age'])
# Text(0.5, 1.0, 'Histogram of Age')

# %%
ax = plt.subplots()
ax = sns.countplot(x='sex', data=titanics)
ax.set_title('남여 승객수')
ax.set_xlabel('Count')
ax.set_ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
import matplotlib.pyplot as plt

labels = '사망', '생존'
xc = titanics['survived'].value_counts()
explode = (0, 0.1)

fig1, ax1 = plt.subplots()
ax1.pie(xc, explode=explode, labels=labels, autopct='%1.1f%%',
       shadow=True, startangle=90)
ax1.axis('equal')
plt.show()
